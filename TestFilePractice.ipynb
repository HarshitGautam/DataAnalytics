# %% [markdown]
# ### Import all the libraries as below

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as pp 
import seaborn
from collections import Counter

# %% [markdown]
# ### To get the graph and plot in this note book itself

# %%
# %matplotlib inline

# %% [markdown]
# ### To get the graph and plot in this note book itself

# %%
df = pd.read_excel('C:/Users/hgsgautam/Desktop/Python/TestFile.xlsx')

# %% [markdown]
# ### A Dataframe looks like this

# %%
df
# Out:
#    Name  YearsExperience  Salary State Sex  \
# 0     A              1.1   39343    AZ   M
# 1     B              1.3   46205    GA   F
# 2     C              1.5   37731    IL   M
# 3     D              2.0   43525    CA   F
# 4     E              2.2   39891    OR   F
# 5     F              2.9   56642    NC   F
# 6     G              3.0   60150    TX   F
# 7     H              3.2   54445    VA   M
# 8     I              3.2   64445    MO   M
# 9     J              3.7   57189    CT   F
# 10    K              3.9   63218    AZ   M
# 11    L              4.0   55794    GA   F
# 12    M              4.0   56957    IL   M
# 13    N              4.1   57081    CA   F
# 14    O              4.5   61111    OR   F
# 15    P              4.9   67938    NC   F
# 16    Q              5.1   66029    TX   F
# 17    R              5.3   83088    VA   M
# 18    S              5.9   81363    MO   M
# 19    T              6.0   93940    CT   F
# 20    U              6.8   91738    AZ   M
# 21    V              7.1   98273    GA   F
# 22    W              7.9  101302    IL   M
# 23    X              8.2  113812    CA   F
# 24    Y              8.7  109431    OR   F
# 25    Z              9.0  105582    NC   F
# 26   AA              9.5  116969    TX   F
# 27   BB              9.6  112635    VA   M
# 28   CC             10.3  122391    MO   M
# 29   DD             10.5  121872    CT   F
#
#                                              Feedback
# 0                                   Doesn't Recommend
# 1                                    Positive Outlook
# 2                                   No opinion of CEO
# 3   worked at Bank of America full-time (More than...
# 4                                      Pay is decent.
# 5   If you are willing to work full-time and have ...
# 6   You acquire a lot of paid vacation time, and t...
# 7   Teammates are often friendly, and like to have...
# 8   If you are good at referring clients to banker...
# 9            The bank is not open on Sunday.Show Less
# 10  There are some angry customers that come throu...
# 11  There are some angry customers that come throu...
# 12  You sometimes deal with abusive people who wil...
# 13  Sometimes financial centers get really busy be...
# 14  Solid way to get your feet wet and get your fo...
# 15  I have spent most of my career in Bank Of Amer...
# 16  sometimes this position can be somewhat of a b...
# 17                               Advice to Management
# 18  It would be nice to see a structured client as...
# 19                   Lots of networking opportunities
# 20                             Many employee networks
# 21                                    Competitive PTO
# 22             Opportunity to try different functions
# 23  Too many changes with mid/top level management...
# 24   The core culture isn't executed at each division
# 25  Vertical career progression might be challengi...
# 26                               Advice to Management
# 27  Make sure people 3 levels down from you are st...
# 28  Recognize employee worth. If it wasn't such a ...
# 29  I'm opposed to the second shift schedule based...

# %% [markdown]
# ### Plot graph example

# %%
df.plot(x='YearsExperience', y= 'Salary')

# %% [markdown]
# ### Scatter plot example

# %%
 pp.scatter(df.YearsExperience, df.Salary)

# %% [markdown]
# ### Some groupby examples

# %%
groupedBy =  df.groupby(['Sex', 'State']).mean()

# %%
print(groupedBy)
# Out:
#            YearsExperience  Salary
# Sex State
# F   CA            4.766667   71472
#     CT            6.733333   91000
#     GA            4.133333   66757
#     NC            5.600000   76720
#     OR            5.133333   70144
#     TX            5.866667   81049
# M   AZ            3.933333   64766
#     IL            4.466667   65330
#     MO            6.466667   89399
#     VA            6.033333   83389

# %%
groupedBy
# Out:
#            YearsExperience  Salary
# Sex State
# F   CA            4.766667   71472
#     CT            6.733333   91000
#     GA            4.133333   66757
#     NC            5.600000   76720
#     OR            5.133333   70144
#     TX            5.866667   81049
# M   AZ            3.933333   64766
#     IL            4.466667   65330
#     MO            6.466667   89399
#     VA            6.033333   83389

# %%
groupedBy.Salary.plot.bar();

# %%
groupedBySex =  df.groupby('Sex').mean()

# %%
groupedBySex
# Out:
#      YearsExperience        Salary
# Sex
# F           5.372222  76190.777778
# M           5.225000  75721.333333

# %%
groupedBySex.Salary.plot.bar();

# %% [markdown]
# ### Counter example
# ###### for counter you need to import counter from collections

# %%
SexCount = pd.DataFrame(Counter(df.Sex).most_common(10), columns=['Sex', 'N'])

# %%
SexCount
# Out:
#   Sex   N
# 0   F  18
# 1   M  12

# %% [markdown]
# ### Selecting subset of rows
# ###### Suppose you want to select row with sex == 'M'

# %%
newDf = df[df.Sex == 'M']

# %%
newDf
# Out:
#    Name  YearsExperience  Salary State Sex  \
# 0     A              1.1   39343    AZ   M
# 2     C              1.5   37731    IL   M
# 7     H              3.2   54445    VA   M
# 8     I              3.2   64445    MO   M
# 10    K              3.9   63218    AZ   M
# 12    M              4.0   56957    IL   M
# 17    R              5.3   83088    VA   M
# 18    S              5.9   81363    MO   M
# 20    U              6.8   91738    AZ   M
# 22    W              7.9  101302    IL   M
# 27   BB              9.6  112635    VA   M
# 28   CC             10.3  122391    MO   M
#
#                                              Feedback
# 0                                   Doesn't Recommend
# 2                                   No opinion of CEO
# 7   Teammates are often friendly, and like to have...
# 8   If you are good at referring clients to banker...
# 10  There are some angry customers that come throu...
# 12  You sometimes deal with abusive people who wil...
# 17                               Advice to Management
# 18  It would be nice to see a structured client as...
# 20                             Many employee networks
# 22             Opportunity to try different functions
# 27  Make sure people 3 levels down from you are st...
# 28  Recognize employee worth. If it wasn't such a ...

# %%
newDfMultiple = df[(df.Sex == 'M') & (df.Salary < 100000) & (df.Salary > 60000)]

# %%
newDfMultiple
# Out:
#    Name  YearsExperience  Salary State Sex  \
# 8     I              3.2   64445    MO   M
# 10    K              3.9   63218    AZ   M
# 17    R              5.3   83088    VA   M
# 18    S              5.9   81363    MO   M
# 20    U              6.8   91738    AZ   M
#
#                                              Feedback
# 8   If you are good at referring clients to banker...
# 10  There are some angry customers that come throu...
# 17                               Advice to Management
# 18  It would be nice to see a structured client as...
# 20                             Many employee networks

# %% [markdown]
# ### Sorting a dataframe based upon any particular column

# %%
newDf.sort_values(by = 'Salary', ascending=[1])
# Out:
#    Name  YearsExperience  Salary State Sex  \
# 2     C              1.5   37731    IL   M
# 0     A              1.1   39343    AZ   M
# 7     H              3.2   54445    VA   M
# 12    M              4.0   56957    IL   M
# 10    K              3.9   63218    AZ   M
# 8     I              3.2   64445    MO   M
# 18    S              5.9   81363    MO   M
# 17    R              5.3   83088    VA   M
# 20    U              6.8   91738    AZ   M
# 22    W              7.9  101302    IL   M
# 27   BB              9.6  112635    VA   M
# 28   CC             10.3  122391    MO   M
#
#                                              Feedback
# 2                                   No opinion of CEO
# 0                                   Doesn't Recommend
# 7   Teammates are often friendly, and like to have...
# 12  You sometimes deal with abusive people who wil...
# 10  There are some angry customers that come throu...
# 8   If you are good at referring clients to banker...
# 18  It would be nice to see a structured client as...
# 17                               Advice to Management
# 20                             Many employee networks
# 22             Opportunity to try different functions
# 27  Make sure people 3 levels down from you are st...
# 28  Recognize employee worth. If it wasn't such a ...

# %% [markdown]
# ### Updating a column for your need example

# %%
SexAbb = df.Sex
dftest1 = df
Sex_new = []
for i in SexAbb:
    Sex_new.append(i + 'x')

dftest1.Sex = Sex_new

# %%
dftest1
# Out:
#    Name  YearsExperience  Salary State Sex  \
# 0     A              1.1   39343    AZ  Mx
# 1     B              1.3   46205    GA  Fx
# 2     C              1.5   37731    IL  Mx
# 3     D              2.0   43525    CA  Fx
# 4     E              2.2   39891    OR  Fx
# 5     F              2.9   56642    NC  Fx
# 6     G              3.0   60150    TX  Fx
# 7     H              3.2   54445    VA  Mx
# 8     I              3.2   64445    MO  Mx
# 9     J              3.7   57189    CT  Fx
# 10    K              3.9   63218    AZ  Mx
# 11    L              4.0   55794    GA  Fx
# 12    M              4.0   56957    IL  Mx
# 13    N              4.1   57081    CA  Fx
# 14    O              4.5   61111    OR  Fx
# 15    P              4.9   67938    NC  Fx
# 16    Q              5.1   66029    TX  Fx
# 17    R              5.3   83088    VA  Mx
# 18    S              5.9   81363    MO  Mx
# 19    T              6.0   93940    CT  Fx
# 20    U              6.8   91738    AZ  Mx
# 21    V              7.1   98273    GA  Fx
# 22    W              7.9  101302    IL  Mx
# 23    X              8.2  113812    CA  Fx
# 24    Y              8.7  109431    OR  Fx
# 25    Z              9.0  105582    NC  Fx
# 26   AA              9.5  116969    TX  Fx
# 27   BB              9.6  112635    VA  Mx
# 28   CC             10.3  122391    MO  Mx
# 29   DD             10.5  121872    CT  Fx
#
#                                              Feedback
# 0                                   Doesn't Recommend
# 1                                    Positive Outlook
# 2                                   No opinion of CEO
# 3   worked at Bank of America full-time (More than...
# 4                                      Pay is decent.
# 5   If you are willing to work full-time and have ...
# 6   You acquire a lot of paid vacation time, and t...
# 7   Teammates are often friendly, and like to have...
# 8   If you are good at referring clients to banker...
# 9            The bank is not open on Sunday.Show Less
# 10  There are some angry customers that come throu...
# 11  There are some angry customers that come throu...
# 12  You sometimes deal with abusive people who wil...
# 13  Sometimes financial centers get really busy be...
# 14  Solid way to get your feet wet and get your fo...
# 15  I have spent most of my career in Bank Of Amer...
# 16  sometimes this position can be somewhat of a b...
# 17                               Advice to Management
# 18  It would be nice to see a structured client as...
# 19                   Lots of networking opportunities
# 20                             Many employee networks
# 21                                    Competitive PTO
# 22             Opportunity to try different functions
# 23  Too many changes with mid/top level management...
# 24   The core culture isn't executed at each division
# 25  Vertical career progression might be challengi...
# 26                               Advice to Management
# 27  Make sure people 3 levels down from you are st...
# 28  Recognize employee worth. If it wasn't such a ...
# 29  I'm opposed to the second shift schedule based...

# %%
SexAbb = df.Sex
dftest1 = df
Sex_new = []
for i in SexAbb:
    Sex_new.append(i[0])

dftest1.Sex = Sex_new

# %%
Sex_new
# Out:
# [u'M',
#  u'F',
#  u'M',
#  u'F',
#  u'F',
#  u'F',
#  u'F',
#  u'M',
#  u'M',
#  u'F',
#  u'M',
#  u'F',
#  u'M',
#  u'F',
#  u'F',
#  u'F',
#  u'F',
#  u'M',
#  u'M',
#  u'F',
#  u'M',
#  u'F',
#  u'M',
#  u'F',
#  u'F',
#  u'F',
#  u'F',
#  u'M',
#  u'M',
#  u'F']

# %%
df
# Out:
#    Name  YearsExperience  Salary State Sex  \
# 0     A              1.1   39343    AZ   M
# 1     B              1.3   46205    GA   F
# 2     C              1.5   37731    IL   M
# 3     D              2.0   43525    CA   F
# 4     E              2.2   39891    OR   F
# 5     F              2.9   56642    NC   F
# 6     G              3.0   60150    TX   F
# 7     H              3.2   54445    VA   M
# 8     I              3.2   64445    MO   M
# 9     J              3.7   57189    CT   F
# 10    K              3.9   63218    AZ   M
# 11    L              4.0   55794    GA   F
# 12    M              4.0   56957    IL   M
# 13    N              4.1   57081    CA   F
# 14    O              4.5   61111    OR   F
# 15    P              4.9   67938    NC   F
# 16    Q              5.1   66029    TX   F
# 17    R              5.3   83088    VA   M
# 18    S              5.9   81363    MO   M
# 19    T              6.0   93940    CT   F
# 20    U              6.8   91738    AZ   M
# 21    V              7.1   98273    GA   F
# 22    W              7.9  101302    IL   M
# 23    X              8.2  113812    CA   F
# 24    Y              8.7  109431    OR   F
# 25    Z              9.0  105582    NC   F
# 26   AA              9.5  116969    TX   F
# 27   BB              9.6  112635    VA   M
# 28   CC             10.3  122391    MO   M
# 29   DD             10.5  121872    CT   F
#
#                                              Feedback
# 0                                   Doesn't Recommend
# 1                                    Positive Outlook
# 2                                   No opinion of CEO
# 3   worked at Bank of America full-time (More than...
# 4                                      Pay is decent.
# 5   If you are willing to work full-time and have ...
# 6   You acquire a lot of paid vacation time, and t...
# 7   Teammates are often friendly, and like to have...
# 8   If you are good at referring clients to banker...
# 9            The bank is not open on Sunday.Show Less
# 10  There are some angry customers that come throu...
# 11  There are some angry customers that come throu...
# 12  You sometimes deal with abusive people who wil...
# 13  Sometimes financial centers get really busy be...
# 14  Solid way to get your feet wet and get your fo...
# 15  I have spent most of my career in Bank Of Amer...
# 16  sometimes this position can be somewhat of a b...
# 17                               Advice to Management
# 18  It would be nice to see a structured client as...
# 19                   Lots of networking opportunities
# 20                             Many employee networks
# 21                                    Competitive PTO
# 22             Opportunity to try different functions
# 23  Too many changes with mid/top level management...
# 24   The core culture isn't executed at each division
# 25  Vertical career progression might be challengi...
# 26                               Advice to Management
# 27  Make sure people 3 levels down from you are st...
# 28  Recognize employee worth. If it wasn't such a ...
# 29  I'm opposed to the second shift schedule based...

# %% [markdown]
# ### Word Cloud

# %%
from nltk.tokenize import word_tokenize
from wordcloud import STOPWORDS
from scipy.misc import imread
from wordcloud import WordCloud
from PIL import Image
from os import path

# %%
 wordcloud = WordCloud(width = 2000, height = 1000).generate(' '.join(df['Feedback']))

# %%
pp.figure(figsize=(30,16))

# %%
pp.imshow(wordcloud)
