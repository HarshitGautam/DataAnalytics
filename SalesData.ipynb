# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as pp 
import seaborn
from collections import Counter
from numpy import math

# %%
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/hgsgautam/Desktop/Python/PythonGIT/Wk.csv')

# %%
df
# Out:
#          Unnamed: 0  Check Number Transaction Date/Time  \
# 0                 0          1079   10/10/2013 12:15 PM
# 1                 1          1079   10/10/2013 12:15 PM
# 2                 2          1079   10/10/2013 12:15 PM
# 3                 3          1080   10/10/2013 12:16 PM
# 4                 4          1080   10/10/2013 12:16 PM
# 5                 5          1081   10/10/2013 12:23 PM
# 6                 6          1081    10/10/2013 1:14 PM
# 7                 7          1085    10/10/2013 1:38 PM
# 8                 8          1085    10/10/2013 1:38 PM
# 9                 9          1085    10/10/2013 1:38 PM
# 10               10          1085    10/10/2013 1:38 PM
# 11               11          1086    10/10/2013 2:20 PM
# 12               12          1086    10/10/2013 2:20 PM
# 13               13          1086    10/10/2013 2:20 PM
# 14               14          1086    10/10/2013 2:20 PM
# 15               15          1086    10/10/2013 2:20 PM
# ...

# %%
new_path = 'C:/Users/hgsgautam/Desktop/Python/PythonGIT/Wk4.txt'
result = open(new_path,'w')

# %%
x = ""
prev = 0
for index, row in df.iterrows():
    if(row['Check Number'] == prev):
        if(str(row['Line Total']) != 'NaN'):
            x = x + "," +row['Item Name']
    else:
        if(str(row['Line Total']) != 'NaN'):
            result.write(x + '\n')
            x = "" + row['Item Name']
            prev = row['Check Number']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-2d33e71bfab4> in <module>()
#       4     if(row['Check Number'] == prev):
#       5         if(str(row['Line Total']) != 'NaN'):
# ----> 6             x = x + "," +row['Item Name']
#       7     else:
#       8         if(str(row['Line Total']) != 'NaN'):
#
# C:\Users\hgsgautam\Anaconda2.1\lib\site-packages\pandas\core\series.pyc in __getitem__(self, key)
#     581         key = com._apply_if_callable(key, self)
#     582         try:
# --> 583             result = self.index.get_value(self, key)
#     584
#     585             if not lib.isscalar(result):
#
# C:\Users\hgsgautam\Anaconda2.1\lib\site-packages\pandas\indexes\base.pyc in get_value(self, series, key)
#    1977         k = self._convert_scalar_indexer(k, kind='getitem')
#    1978         try:
# -> 1979             return self._engine.get_value(s, k,
# ...

# %%
class(df.Check Number)
# Out:
#   File "<ipython-input-10-fa887a888fc5>", line 1
#     class(df.Check Number)
#          ^
# SyntaxError: invalid syntax

# %%
new_path = 'C:/Users/hgsgautam/Desktop/Python/PythonGIT/Wk.txt'
new_days = open(new_path,'w')

title = 'Days of the Week\n'
print(title)
new_days.write(title)
# Out:
# Days of the Week
